# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Pempho Mwinjilo

# %% [markdown]
# I currently work as a planner in the public sector of Malawi

# %% [markdown]
# *I am interested in data science because it is a great career change where I will be able to create solutions to problems that I never imagined could have solutions

# %% [markdown]
# ## my code will add 1 and 1 in the next cell

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# * Bullet list
# * second bullet
# * third bullet
# * fourth bullet
#
# 1. Number list
# 2. Second number
# 3. Third number
# 4. Fourth number
#
# ***
# Here is an important text
# ***
